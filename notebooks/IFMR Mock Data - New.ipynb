# %% [markdown]
# # Constraining the Initial-Final Mass Relation using Wide Double White Dwarfs

# %% [markdown]
# <div style="text-align: center; font-size: 120%;">
# Jeff J. Andrews (Columbia) <br/>
# Marcel A. Agüeros (Columbia) <br/>
# Alexandros Gianninas (Oklahoma) <br/>
# Mukremin Kilic (Oklahoma) <br/>
# Saurav Dhital (Embry-Riddle) <br/>
# Scott Anderson (Washington) <br/>
# </div>

# %% [markdown]
# ### Load the data

# %%
import os
import emcee
import triangle
import time
from scipy.stats import truncnorm, norm
from scipy.interpolate import interp1d
from scipy import integrate
import scipy.optimize as opt
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
import pylab as P
# %matplotlib inline


# Import MESA lifetimes
#datafile = os.path.abspath("../data/test_lifetime.dat")
datafile = os.path.abspath("../data/MESA_lifetime.dat")
names = ["name","lifetime"]
MESA_tcool = np.genfromtxt(datafile, dtype=None, usecols=range(len(names)), names=names)

# Move to log10 of stellar ages
MESA_tcool["lifetime"] = np.log10(MESA_tcool["lifetime"])

# %% [markdown]
# ### Create function to interpolate between MESA lifetimes

# %%
# Function to interpolate MESA lifetimes
def lifetime(MESA_tcool, M_zams):
    
    lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=1.0e7)
    
    return lifetime(M_zams)


# Function to interpolate M_zams from MESA lifetime (inverse of previous function)
def lifetime_inv(MESA_tcool, tcool):

    # For whatever reason, interp1d requires an increasing function,
    # therefore we create a "view" into the function using the [::-1]
    lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)
    
    return lifetime_inv(tcool)


# Function to return M_zams from M_wd using model
def get_mzams(p, m_wd):
    bt1, th1, th2, th3 = p
    
    # Get slopes from theta's
    m1 = np.tan(th1)
    m2 = np.tan(th2)
    m3 = np.tan(th3)
    
    # Determine b2, b3 as a function of other parameters
    b1 = bt1 / np.cos(th1)
    b2 = (m1-m2) * 2.0 + b1
    b3 = (m2-m3) * 4.0 + b2
    
    # Define array
    M_zams = np.array([])

    # Define piecewise linear model
    conds = [m_wd<b1, (m_wd>b1) & (m_wd<2.0*m1+b1), (m_wd>2.0*m1+b1) & (m_wd<4.0*m2+b2), m_wd>4.0*m2+b2]
    funcs = [lambda m_wd: 0., lambda m_wd: 1./m1*(m_wd-b1), lambda m_wd: 1./m2*(m_wd-b2), lambda m_wd: 1./m3*(m_wd-b3)]

    M_zams = np.piecewise(m_wd, conds, funcs)
    
    return M_zams


# Function to return M_wd from M_zams using model
def get_m_wd(p, m_zams):
    bt1, th1, th2, th3 = p
#    bt1, th1 = p
    
    # Get slopes from theta's
    m1 = np.tan(th1)
    m2 = np.tan(th2)
    m3 = np.tan(th3)
    
    # Determine b2, b3 as a function of other parameters
    b1 = bt1 / np.cos(th1)
    b2 = (m1-m2) * 2.0 + b1
    b3 = (m2-m3) * 4.0 + b2
    
    # Define array
    M_wd = np.array([])

    # Define piecewise linear model
    conds = [m_zams<0.0, (m_zams>0.0) & (m_zams<2.0), (m_zams>2.0) & (m_zams<4.0), m_zams>4.0]
    funcs = [lambda m_zams: 0., lambda m_zams: m1*m_zams+b1, lambda m_zams: m2*m_zams+b2, lambda m_zams: m3*m_zams+b3]
    
    M_wd = np.piecewise(m_zams, conds, funcs)
    
    return M_wd

# %% [markdown]
# ### Generate Fake Data

# %%
def create_mock_data(p_true, N_sys=20):

    # Get random WD masses
    lower = 0.6
    upper = 1.2
    mu = 0.65
    sigma = 0.15
    M1_wd = truncnorm.rvs((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N_sys)

    lower = 0.45
    upper = 1.0
    mu = 1.0
    sigma = 0.15
    mass_ratio = truncnorm.rvs((lower-mu)/sigma,(upper-mu)/sigma,loc=mu,scale=sigma,size=N_sys)
    M2_wd = M1_wd * mass_ratio

    # Determine their ZAMS masses
    M1_zams = get_mzams(p_true, M1_wd)
    M2_zams = get_mzams(p_true, M2_wd)

    # Get the Main Sequence lifetimes from these ZAMS masses
    M1_lifetime = lifetime(MESA_tcool, M1_zams)
    M2_lifetime = lifetime(MESA_tcool, M2_zams)
    delta_MS_lifetime = M2_lifetime-M1_lifetime

    # Get random system ages: log t: Uniform (7.0,9.0)
    age_system = np.power(10.0, np.random.uniform(7.0,9.0,N_sys))
    t1_cool = age_system + delta_MS_lifetime
    t2_cool = age_system 

    # Add fake uncertainties: 10% for cooling age, 0.3 Msun in mass
#    t1_cool = np.random.normal(t1_cool, 0.1*t1_cool)
#    t2_cool = np.random.normal(t2_cool, 0.1*t2_cool)
#    M1_wd = np.random.normal(M1_wd,0.03)
#    M2_wd = np.random.normal(M2_wd,0.03)

    M1_wd_err = 0.03*np.ones(N_sys)
    M2_wd_err = 0.03*np.ones(N_sys)
    t1_cool_err = 0.1 * t1_cool
    t2_cool_err = 0.1 * t2_cool

    # Move data into structure "DWD"
    dtype=[('m1_wd','float64'),('m1_wd_err','float64'),('m2_wd','float64'),('m2_wd_err','float64'),
                      ('age1','float64'),('age1_err','float64'),('age2','float64'),('age2_err','float64')]

    DWD = np.zeros(N_sys, dtype=dtype)
    DWD["m1_wd"] = np.copy(M1_wd)
    DWD["m1_wd_err"] = np.copy(M1_wd_err)
    DWD["m2_wd"] = np.copy(M2_wd)
    DWD["m2_wd_err"] = np.copy(M2_wd_err)
    DWD["age1"] = np.copy(t1_cool)
    DWD["age1_err"] = np.copy(t1_cool_err)
    DWD["age2"] = np.copy(t2_cool)
    DWD["age2_err"] = np.copy(t2_cool_err)

    return DWD

# %% [markdown]
# ### Functions for likelihood, prior, posterior, etc. for 3-piecewise linear model

# %%
# Function for optimization
def temp_func(x, delta_time, delta_cool_err, jacobian):
    arg = jacobian * np.exp(-(delta_time - x)*(delta_time - x)/(2. * delta_cool_err*delta_cool_err))
    arg[np.isinf(arg)] = 0.0
#    print x, -np.sum(arg)
    return -np.sum(arg)

def temp_func_deriv(x, delta_time, delta_cool_err):
#    a = (temp_func(x+100.0, delta_time, delta_cool_err) - temp_func(x, delta_time, delta_cool_err))/100.0    
    arg = np.exp(-(delta_time - x)*(delta_time - x)/(2. * delta_cool_err*delta_cool_err))
    arg[np.isinf(arg)] = 0.0
#    print a, -np.sum((delta_time - x)/(delta_cool_err*delta_cool_err) * arg)
    return -np.sum((delta_time - x)/(delta_cool_err*delta_cool_err) * arg)
#    return a


# Calculate likelihood function
def ln_likelihood(p, MESA_tcool, DWD):
    

    # Define lifetime interpolation functions
    func_lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=1.0e7)    
    func_lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)
    
    
    # Number of samples for our Monte Carlo integration
    N_samp = 1024
#    N_samp = 20000
    
    # Limit the WD mass to be confined within this range
    wd_lower = 0.5    # Lowest allowed WD mass
    wd_upper = 1.4    # Highest allowed WD mass
    # First determine upper and lower
    zams_limits = np.array([min(MESA_tcool["name"]), max(MESA_tcool["name"])])
    wd_limits = get_m_wd(p, zams_limits)
    t_limits = func_lifetime(zams_limits)
    lower = wd_limits[0]
    upper = wd_limits[1]


    # Create probability array
    P_sys = np.array([])
    dist_wd1 = np.array([])
    dist_wd2 = np.array([])

       
    # Calculate each system individually
    for sys in DWD:

        # Define array of cooling age differences
        delta_cool = sys["age2"] - sys["age1"]
        delta_cool_err = np.sqrt(sys["age1_err"]*sys["age1_err"] + sys["age2_err"]*sys["age2_err"])
                
        # Define [truncated] normal distributions for WD masses
        dist_wd1 = truncnorm.rvs((lower - sys["m1_wd"]) / sys["m1_wd_err"], (upper - sys["m1_wd"]) / sys["m1_wd_err"], loc=sys["m1_wd"], scale=sys["m1_wd_err"], size=N_samp)
        dist_wd2 = truncnorm.rvs((lower - sys["m2_wd"]) / sys["m2_wd_err"], (upper - sys["m2_wd"]) / sys["m2_wd_err"], loc=sys["m2_wd"], scale=sys["m2_wd_err"], size=N_samp)    
    
        # Calculate zams masses
        dist_zams1 = get_mzams(p, dist_wd1)
        dist_zams2 = get_mzams(p, dist_wd2)
        
        # Calculate MS lifetimes
        dist_time1 = func_lifetime(dist_zams1)
        dist_time2 = func_lifetime(dist_zams2)

        
        # To adjust based on jacobian
        dm_wd_dm_zams1 = 1.0e-4 / (get_mzams(p, dist_wd1 + 1.0e-4) - get_mzams(p, dist_wd1))
        dm_zams_dt_ms1 = (func_lifetime_inv(dist_time1 + 1.0e4) - func_lifetime_inv(dist_time1)) / 1.0e4

        dm_wd_dm_zams2 = 1.0e-4 / (get_mzams(p, dist_wd2 + 1.0e-4) - get_mzams(p, dist_wd2))
        dm_zams_dt_ms2 = (func_lifetime_inv(dist_time2 + 1.0e4) - func_lifetime_inv(dist_time2)) / 1.0e4
        coeff_norm = (N_samp + 0.0) / np.sum(dm_zams_dt_ms1*dm_wd_dm_zams1 * dm_zams_dt_ms2*dm_wd_dm_zams2)
        

        # Now compare difference in lifetimes to difference in cooling ages
        delta_time = dist_time1 - dist_time2

        avg_delta_time = np.sum(delta_time) / (N_samp + 0.0)

        jacobian = dm_zams_dt_ms1 * dm_zams_dt_ms2 * dm_wd_dm_zams1 * dm_wd_dm_zams2
        
        # To find the maximum likelihood delta_cool
#        meth = 'BFGS'
#        meth = 'CG'
        meth = 'Powell'
#        meth = 'Nelder-Mead'
        result = opt.minimize(temp_func, delta_cool, args=(delta_time, delta_cool_err, jacobian), method=meth, tol=1.0e-5)
#        result = opt.minimize(temp_func, delta_cool, args=(delta_time, delta_cool_err), method=meth, tol=1.0e-4, jac=temp_func_deriv)    
#        xmin = opt.fmin_cg(temp_func, 0.0, args=(delta_time, delta_cool_err), maxiter = 10, full_output=0, disp=1, gtol=1.0e-8)
        xmin = result.x
        
        # P( delta t_cool | M1_zams_t, M2_zams_t)
        coeff = 1./(delta_cool_err * np.sqrt(2. * np.pi))
        argument = np.exp(-(delta_time - delta_cool)*(delta_time - delta_cool)/(2. * delta_cool_err*delta_cool_err))
        argument2 = np.exp(-(delta_time - xmin)*(delta_time - xmin)/(2. * delta_cool_err*delta_cool_err))
          
        # Priors on the hyperparameters
        P_sys_prior = coeff_norm * (dm_zams_dt_ms1 * dm_zams_dt_ms2 * dm_wd_dm_zams1 * dm_wd_dm_zams2)
#        P_sys_prior = coeff_norm * (dm_zams_dt_ms1 * dm_zams_dt_ms2)
    
        # This is the value of the integrand
        P_sys_temp = P_sys_prior * coeff * argument
        P_sys_temp2 = P_sys_prior * coeff * argument2
        P_sys_temp[np.isinf(P_sys_temp)] = 0.0
        P_sys_temp2[np.isinf(P_sys_temp2)] = 0.0

        P_sys = np.append(P_sys, np.sum(P_sys_temp) / np.sum(P_sys_temp2))
#        P_sys = np.append(P_sys, np.sum(P_sys_temp) / (N_samp + 0.0))
        
    ln_P_sys = np.log(P_sys)            
    ln_P_sys[np.isnan(ln_P_sys)] = -np.inf
    
    
    return ln_P_sys 



# The prior functions
def ln_prior(p):
    bt1, th1, th2, th3 = p

    b1 = bt1 / np.cos(th1)

    # Get slopes from theta's
    m1 = np.tan(th1)
    m2 = np.tan(th2)
    m3 = np.tan(th3)
    
    # Determine b2, b3 as a function of other parameters
    b2 = (m1-m2) * 2.0 + b1
    b3 = (m2-m3) * 4.0 + b2
    
    lp = 0.
    
    # Limit the x-intercept: b = [0,0.5]
    if b1 < 0. or b1 > 0.5:
        return -np.inf
    
    # The slopes must all be positive
    # This corresponds to theta = [0,pi/2]
    if th1 < 0. or th1 > np.pi/2.:
        return -np.inf
    if th2 < 0. or th2 > np.pi/2.:
        return -np.inf
    if th3 < 0. or th3 > np.pi/2.:
        return -np.inf
    
    
    # Require that M_zams=7 becomes a WD (M_wd < 1.4)
    if 7.0*m3+b3 > 1.4 or 7.0*m3+b3 < 1.0:
        return -np.inf
    
    
    return lp


# The posterior function calls the likelihood and prior functions
def ln_posterior(p, MESA_tcool, DWD):
    
    # Check prior on model first
    lp = ln_prior(p)
    
    if np.any(np.isnan(lp)):
        return -np.inf

    # Then check likelihood of parameters
#    ll = ln_likelihood(p, MESA_tcool, DWD)
    ll = ln_likelihood_test_2(p, DWD)
    
    if np.any(np.isnan(ll) | np.isinf(ll)):
        return -np.inf

    
    if np.all(ll == 0.):
        return -np.inf
    
    return lp + ll.sum()

# %% [markdown]
# ### Wrapper for emcee

# %%
# This function runs emcee
def run_inference(MESA_tcool, DWD, p_true, nwalkers=32, nburn=200, nsteps=1000):
    # number of parameters
    ndim = 4

    # initial positions for walkers
    p0 = np.zeros((nwalkers,ndim))
    p0[:,0] = np.random.normal(p_true[0], 0.01, size=nwalkers) # b1
    p0[:,1] = np.random.normal(p_true[1], 0.01, size=nwalkers) # theta_1
    p0[:,2] = np.random.normal(p_true[2], 0.03, size=nwalkers) # theta_2
    p0[:,3] = np.random.normal(p_true[3], 0.03, size=nwalkers) # theta_3
    
    args = (MESA_tcool, DWD)
    sampler = emcee.EnsembleSampler(nwalkers=nwalkers, dim=ndim, lnpostfn=ln_posterior, args=args)

    # burn-in
    sampler.run_mcmc(p0, N=nburn)
    pos,prob,state = sampler.run_mcmc(p0, N=nburn)

    # throw out burn-in samples
    sampler.reset() 
    pos,prob,state = sampler.run_mcmc(pos, N=nsteps)

    
    return sampler

# %% [markdown]
# ### Run emcee

# %%
t_start = time.clock()

p_true_1 = np.array([0.1, 0.1, 0.38, 0.05])
N_sys_1 = 10
DWD_1 = create_mock_data(p_true_1, N_sys_1)
sampler_1 = run_inference(MESA_tcool, DWD_1, p_true_1, nburn=2, nsteps=2)
print "Mock data set 1 finished"

print "Elapsed time:", time.clock() - t_start, "seconds"
# Out:
# /Library/Python/2.7/site-packages/emcee/ensemble.py:335: RuntimeWarning: invalid value encountered in subtract
#   lnpdiff = (self.dim - 1.) * np.log(zz) + newlnprob - lnprob0
# /Library/Python/2.7/site-packages/emcee/ensemble.py:336: RuntimeWarning: invalid value encountered in greater
#   accept = (lnpdiff > np.log(self._random.rand(len(lnpdiff))))
# -c:79: RuntimeWarning: invalid value encountered in log
# Mock data set 1 finished
# Elapsed time: 12881.979476 seconds

# %%
p_true_2 = np.array([0.1, 0.1, 0.38, 0.05])
N_sys_2 = 50
DWD_2 = create_mock_data(p_true_2, N_sys_2)
sampler_2 = run_inference(MESA_tcool, DWD_2, p_true_2, nburn=200, nsteps=800)
print "Mock data set 2 finished"
# Out:
# Mock data set 2 finished

# %%
p_true_3 = np.array([0.096, 0.291, 0.10, 0.08])
N_sys_3 = 20
DWD_3 = create_mock_data(p_true_3, N_sys_3)
sampler_3 = run_inference(MESA_tcool, DWD_3, p_true_3, nburn=100, nsteps=200)
print "Mock data set 3 finished"
# Out:
# Mock data set 3 finished

# %%
p_true_4 = np.array([0.096, 0.291, 0.10, 0.08])
N_sys_4 = 50
DWD_4 = create_mock_data(p_true_4, N_sys_4)
#sampler_4 = run_inference(MESA_tcool, DWD_4, p_true_4, nburn=100, nsteps=200)
print "Mock data set 4 finished"
# Out:
# Mock data set 4 finished

# %% [markdown]
# ### Create posterior covariance plots - N=40

# %%
labels = ["$b_{t,1}$", r"$\theta_1$", r"$\theta_2$", r"$\theta_3$"]
extents = [(-0.05, 0.55), (-0.05,0.4), (0.00,0.55), (-0.02,0.2)]

#labels = ["$b_1$", r"$\theta_1$"]
#extents = [(0.0, 0.5), (0.0,np.pi/2.)]

fig = triangle.corner(sampler_2.flatchain, truths=p_true_2, labels=labels, extents=extents)

fig.savefig('../figures/triangle_2.pdf')

# %% [markdown]
# ### Testing likelihood function

# %%
# Calculate likelihood function
def ln_likelihood_test(p, MESA_tcool, DWD):
    

    # Define lifetime interpolation functions
    func_lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=1.0e7)    
    func_lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)
    
    
    # Number of samples for our Monte Carlo integration
#    N_samp = 1024
    N_samp = 20000
    
    # Limit the WD mass to be confined within this range
    wd_lower = 0.5    # Lowest allowed WD mass
    wd_upper = 1.4    # Highest allowed WD mass
    # First determine upper and lower
    zams_limits = np.array([min(MESA_tcool["name"]), max(MESA_tcool["name"])])
    wd_limits = get_m_wd(p, zams_limits)
    t_limits = func_lifetime(zams_limits)
    lower = wd_limits[0]
    upper = wd_limits[1]


    # Create probability array
    P_sys = np.array([])
    dist_wd1 = np.array([])
    dist_wd2 = np.array([])
    statistic = np.array([])
       
    # Calculate each system individually
    for sys in DWD:

        # Define array of cooling age differences
        delta_cool = sys["age2"] - sys["age1"]
        delta_cool_err = np.sqrt(sys["age1_err"]*sys["age1_err"] + sys["age2_err"]*sys["age2_err"])
                
        # Define [truncated] normal distributions for WD masses
        dist_wd1 = truncnorm.rvs((lower - sys["m1_wd"]) / sys["m1_wd_err"], (upper - sys["m1_wd"]) / sys["m1_wd_err"], loc=sys["m1_wd"], scale=sys["m1_wd_err"], size=N_samp)
        dist_wd2 = truncnorm.rvs((lower - sys["m2_wd"]) / sys["m2_wd_err"], (upper - sys["m2_wd"]) / sys["m2_wd_err"], loc=sys["m2_wd"], scale=sys["m2_wd_err"], size=N_samp)    
    
        # Calculate zams masses
        dist_zams1 = get_mzams(p, dist_wd1)
        dist_zams2 = get_mzams(p, dist_wd2)
        
        # Calculate MS lifetimes
        dist_time1 = func_lifetime(dist_zams1)
        dist_time2 = func_lifetime(dist_zams2)

        
        # To adjust based on jacobian
        dm_wd_dm_zams1 = 1.0e-4 / (get_mzams(p, dist_wd1 + 1.0e-4) - get_mzams(p, dist_wd1))
        dm_zams_dt_ms1 = (func_lifetime_inv(dist_time1 + 1.0e4) - func_lifetime_inv(dist_time1)) / 1.0e4

        dm_wd_dm_zams2 = 1.0e-4 / (get_mzams(p, dist_wd2 + 1.0e-4) - get_mzams(p, dist_wd2))
        dm_zams_dt_ms2 = (func_lifetime_inv(dist_time2 + 1.0e4) - func_lifetime_inv(dist_time2)) / 1.0e4

        w_k = 1.0 / (dm_zams_dt_ms1 * dm_zams_dt_ms2 * dm_wd_dm_zams1 * dm_wd_dm_zams2)

        # Now compare difference in lifetimes to difference in cooling ages
        delta_time = dist_time1 - dist_time2
        
        # P( delta t_cool | M1_zams_t, M2_zams_t)
        coeff = 1./(delta_cool_err * np.sqrt(2. * np.pi))
        argument = np.exp(-(delta_time - delta_cool)*(delta_time - delta_cool)/(2. * delta_cool_err*delta_cool_err))
                  
        P_sys = np.append(P_sys, np.sum(w_k * coeff * argument) / np.sum(w_k))
        
        statistic = np.append(statistic, np.sum(w_k)*np.sum(w_k) / np.sum(w_k * w_k))
        
    ln_P_sys = np.log(P_sys)            
    ln_P_sys[np.isnan(ln_P_sys)] = -np.inf
    
    return ln_P_sys
#    return (ln_P_sys, statistic)

# %%
def create_mock_data_test(p_true, N_sys=20, error=0.03):

#    M1_wd = 0.7 * np.ones(N_sys)
    M1_wd = np.linspace(0.50, 0.7, N_sys)
    M2_wd = 0.5 * np.ones(N_sys)
    #    M2_wd = 0.6 * np.ones(N_sys)
#    M2_wd = np.linspace(0.5, 0.7, N_sys)    

    # Determine their ZAMS masses
    M1_zams = get_mzams(p_true, M1_wd)
    M2_zams = get_mzams(p_true, M2_wd)
#    M1_zams = get_mzams_2(p_true, M1_wd)
#    M2_zams = get_mzams_2(p_true, M2_wd)


    # Get the Main Sequence lifetimes from these ZAMS masses
    M1_lifetime = lifetime(MESA_tcool, M1_zams)
    M2_lifetime = lifetime(MESA_tcool, M2_zams)
    delta_MS_lifetime = M2_lifetime-M1_lifetime

    # System age is 1 Gyr
    age_system = np.power(10.0, 7.0)
#    age_system = np.power(10.0,np.linspace(7.0,10.0,N_sys))
    t1_cool = age_system + delta_MS_lifetime
    t2_cool = age_system 

    # Add fake uncertainties: 10% for cooling age, 0.3 Msun in mass
    t1_cool = np.random.normal(t1_cool, 0.1*t1_cool)
    t2_cool = np.random.normal(t2_cool, 0.1*t2_cool)
    M1_wd = np.random.normal(M1_wd,error)
    M2_wd = np.random.normal(M2_wd,error)

    M1_wd_err = error*np.ones(N_sys)
    M2_wd_err = error*np.ones(N_sys)
    t1_cool_err = 0.1 * t1_cool
    t2_cool_err = 0.1 * t2_cool

    # Move data into structure "DWD"
    dtype=[('m1_wd','float64'),('m1_wd_err','float64'),('m2_wd','float64'),('m2_wd_err','float64'),
                      ('age1','float64'),('age1_err','float64'),('age2','float64'),('age2_err','float64')]

    DWD = np.zeros(N_sys, dtype=dtype)
    DWD["m1_wd"] = np.copy(M1_wd)
    DWD["m1_wd_err"] = np.copy(M1_wd_err)
    DWD["m2_wd"] = np.copy(M2_wd)
    DWD["m2_wd_err"] = np.copy(M2_wd_err)
    DWD["age1"] = np.copy(t1_cool)
    DWD["age1_err"] = np.copy(t1_cool_err)
    DWD["age2"] = np.copy(t2_cool)
    DWD["age2_err"] = np.copy(t2_cool_err)

    return DWD

# %%
p_true_2 = np.array([0.1, 0.1, 0.38, 0.05])
N_sys_2 = 20
DWD_2 = create_mock_data_test(p_true_2, N_sys_2)

print DWD_2

#print DWD_2["m1_wd"], DWD_2["m2_wd"], DWD_2["age1"], DWD_2["age2"]
# Out:
# [(0.5, 0.03, 0.5, 0.03, 10000000.0, 1000000.0, 10000000.0, 1000000.0)
#  (0.5105263157894737, 0.03, 0.5, 0.03, 34356658.81642091, 3435665.8816420916, 10000000.0, 1000000.0)
#  (0.5210526315789473, 0.03, 0.5, 0.03, 58713317.63284147, 5871331.763284147, 10000000.0, 1000000.0)
#  (0.531578947368421, 0.03, 0.5, 0.03, 83069976.44926202, 8306997.6449262025, 10000000.0, 1000000.0)
#  (0.5421052631578948, 0.03, 0.5, 0.03, 106816279.43125904, 10681627.943125904, 10000000.0, 1000000.0)
#  (0.5526315789473684, 0.03, 0.5, 0.03, 126177737.76987147, 12617773.776987148, 10000000.0, 1000000.0)
#  (0.5631578947368421, 0.03, 0.5, 0.03, 145539196.10848463, 14553919.610848464, 10000000.0, 1000000.0)
#  (0.5736842105263158, 0.03, 0.5, 0.03, 164900654.44709778, 16490065.444709778, 10000000.0, 1000000.0)
#  (0.5842105263157895, 0.03, 0.5, 0.03, 184262112.78571093, 18426211.278571095, 10000000.0, 1000000.0)
#  (0.5947368421052631, 0.03, 0.5, 0.03, 203623571.12432384, 20362357.112432387, 10000000.0, 1000000.0)
#  (0.6052631578947368, 0.03, 0.5, 0.03, 222985029.462937, 22298502.9462937, 10000000.0, 1000000.0)
#  (0.6157894736842104, 0.03, 0.5, 0.03, 242346487.80155003, 24234648.780155003, 10000000.0, 1000000.0)
#  (0.6263157894736842, 0.03, 0.5, 0.03, 259172435.64376652, 25917243.564376652, 10000000.0, 1000000.0)
#  (0.6368421052631579, 0.03, 0.5, 0.03, 273779931.3802701, 27377993.138027012, 10000000.0, 1000000.0)
#  (0.6473684210526316, 0.03, 0.5, 0.03, 288387427.1167737, 28838742.711677372, 10000000.0, 1000000.0)
#  (0.6578947368421052, 0.03, 0.5, 0.03, 302994922.85327685, 30299492.285327688, 10000000.0, 1000000.0)
#  (0.6684210526315789, 0.03, 0.5, 0.03, 317602418.5897804, 31760241.85897804, 10000000.0, 1000000.0)
#  (0.6789473684210526, 0.03, 0.5, 0.03, 332209914.32628405, 33220991.432628408, 10000000.0, 1000000.0)
#  (0.6894736842105262, 0.03, 0.5, 0.03, 346817410.0627871, 34681741.006278716, 10000000.0, 1000000.0)
#  (0.7, 0.03, 0.5, 0.03, 361424905.7992907, 36142490.579929076, 10000000.0, 1000000.0)]

# %%
#DWD_2["m1_wd_err"] = 0.001
#DWD_2["m2_wd_err"] = 0.001

N_pts = 100
theta2 = np.linspace(0.1, 1.0, N_pts)

like_i = np.array([])
stat_i = np.array([])
sys_1 = np.array([])
sys_2 = np.array([])
sys_3 = np.array([])
sys_4 = np.array([])
sys_5 = np.array([])

for i in theta2:
    p_test = p_true_2.copy()
    p_test[2] = i
    
    
#    temp_c, temp_a = ln_likelihood_test(p_test, MESA_tcool, DWD_2)[0]
#    temp_d, temp_b = ln_likelihood_test(p_test, MESA_tcool, DWD_2)[1]
    ln_like = ln_likelihood_test(p_test, MESA_tcool, DWD_2)

    sys_1 = np.append(sys_1, ln_like[1])
    sys_2 = np.append(sys_2, ln_like[2])
    sys_3 = np.append(sys_3, ln_like[3])
    sys_4 = np.append(sys_4, ln_like[4])
    sys_5 = np.append(sys_5, ln_like[5])
    like_i = np.append(like_i, np.sum(ln_like))
#    stat_i = np.append(stat_i, temp_b)
    

print DWD_2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3e99c180624e> in <module>()
#      20 #    temp_c, temp_a = ln_likelihood_test(p_test, MESA_tcool, DWD_2)[0]
#      21 #    temp_d, temp_b = ln_likelihood_test(p_test, MESA_tcool, DWD_2)[1]
# ---> 22     ln_like = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
#      23
#      24     sys_1 = np.append(sys_1, ln_like[1])
#
# <ipython-input-8-3dd1222a2ff8> in ln_likelihood_test(p, MESA_tcool, DWD)
#      54
#      55         dm_wd_dm_zams2 = 1.0e-4 / (get_mzams(p, dist_wd2 + 1.0e-4) - get_mzams(p, dist_wd2))
# ---> 56         dm_zams_dt_ms2 = (func_lifetime_inv(dist_time2 + 1.0e4) - func_lifetime_inv(dist_time2)) / 1.0e4
#      57
#      58         w_k = 1.0 / (dm_zams_dt_ms1 * dm_zams_dt_ms2 * dm_wd_dm_zams1 * dm_wd_dm_zams2)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/polyint.pyc in __call__(self, x)
#      52         """
#      53         x, x_shape = self._prepare_x(x)
# ---> 54         y = self._evaluate(x)
#      55         return self._finish_y(y, x_shape)
#      56
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     447         x_new = asarray(x_new)
#     448         out_of_bounds = self._check_bounds(x_new)
# --> 449         y_new = self._call(self, x_new)
#     450         if len(y_new) > 0:
#     451             y_new[out_of_bounds] = self.fill_value
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpolate.pyc in _call_linear(self, x_new)
#     414         # Note that the following two expressions rely on the specifics of the
#     415         # broadcasting semantics.
# --> 416         slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#     417
#     418         # 5. Calculate the actual value for each entry in x_new.
#
# KeyboardInterrupt:

# %%
plt.scatter(theta2, like_i)
plt.plot(theta2, like_i)
plt.axvline(p_true_2[2], color="r")
    
plt.xlabel("Theta 2")
plt.ylabel("Ln Likelihood")

plt.xlim(0.2,0.7)
plt.ylim(max(like_i)-10, max(like_i)+2)
#plt.ylim(-75.0, -74.5)

plt.show()
#plt.savefig("../figures/likelihood_test_N100_err03.pdf")
#plt.savefig("../figures/likelihood_test_err001.pdf")

#plt.scatter(theta2, stat_i)
plt.xlabel("Theta 2")
plt.ylabel("sum(w_k)*sum(w_k)/sum(w_k*w_k)")

plt.axvline(p_true_2[2], color="r")
plt.xlim(0.2,0.7)
#plt.ylim(18000,20500)
plt.show()
#plt.savefig("../figures/likelihood_stat_err06.pdf")

# %%
# Now to show the individual likelihoods for two separate systems


#plt.scatter(theta2, sys_1)
plt.plot(theta2, sys_1, label=r'$M_1 =\,0.54\,M_{\odot}$')

#plt.scatter(theta2, sys_2)
plt.plot(theta2, sys_2, label=r'$M_1 =\,0.58\,M_{\odot}$')

#plt.scatter(theta2, sys_3)
plt.plot(theta2, sys_3, label=r'$M_1 =\,0.62\,M_{\odot}$')

#plt.scatter(theta2, sys_4)
plt.plot(theta2, sys_4, label=r'$M_1 =\,0.66\,M_{\odot}$')

#plt.scatter(theta2, sys_5)
plt.plot(theta2, sys_5, label=r'$M_1 =\,0.70\,M_{\odot}$')


plt.axvline(p_true_2[2], color="r")


plt.legend(loc=8, labelspacing=0.01)
plt.text(0.15,-16.0, r'$M_2 =\,0.50\,M_{\odot}$', fontsize=16)

plt.xlabel("Theta 2")
plt.ylabel("Ln Likelihood")

plt.xlim(0.1,0.7)
plt.ylim(max(sys_1)-6, max(sys_1)+2)

plt.show()
#plt.savefig("../figures/likelihood_test_m1_err001.pdf")

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(theta2, sys_5)
plt.xlabel("Theta 2")
plt.ylabel("Ln Likelihood")

plt.xlim(0.1,0.7)
plt.ylim(max(sys_5)-6, max(sys_5)+2)

plt.axvline(0.175, color='g')
plt.text(0.20, -17.0, 'IFMR 1')

plt.axvline(p_true_2[2], color='b')
plt.text(0.40, -17.0, 'IFMR 2')




plt.subplot(1,2,2)
tmp_x = np.linspace(1.0,8.0,1000)

p_2 = np.copy(p_true_2)
p_2[2] = 0.175
tmp_y2 = get_m_wd(p_2,tmp_x)
plt.plot(tmp_x, tmp_y2, color='g', label='IFMR 1')
plt.scatter(get_mzams(p_2,[DWD_2["m1_wd"][5], DWD_2["m2_wd"][5]]), [DWD_2["m1_wd"][5], DWD_2["m2_wd"][5]], color='g')

p_1 = np.copy(p_true_2)
tmp_y1 = get_m_wd(p_1,tmp_x)
plt.plot(tmp_x, tmp_y1, color='b', label='IFMR 2')
plt.scatter(get_mzams(p_1,[DWD_2["m1_wd"][5], DWD_2["m2_wd"][5]]), [DWD_2["m1_wd"][5], DWD_2["m2_wd"][5]], color='b')


# Display WDs
plt.axhline(DWD_2["m1_wd"][5], color='k', linestyle='dotted')
plt.text(1.2, 0.74, "WD 1")
plt.axhline(DWD_2["m2_wd"][5], color='k', linestyle='dotted')
plt.text(1.2, 0.43, "WD 1")


# Display lifetime differences
delta_t = int((DWD_2["age1"][5] - DWD_2["age2"][5]) / 1.0e6)
plt.text(3.5,0.4, r'$\Delta \tau_{\rm cool}$ = '+str(delta_t)+' Myr', fontsize=14)

t_2 = lifetime(MESA_tcool, get_mzams(p_2, [DWD_2["m1_wd"][5], DWD_2["m2_wd"][5]]))
delta_t_2 = int((t_2[1] - t_2[0])/1.0e6)
plt.text(3.0,0.3, r'IFMR 1: $\Delta \tau_{\rm life}$ = '+str(delta_t_2)+' Myr', fontsize=14)

t_1 = lifetime(MESA_tcool, get_mzams(p_1, [DWD_2["m1_wd"][5], DWD_2["m2_wd"][5]]))
delta_t_1 = int((t_1[1] - t_1[0])/1.0e6)
plt.text(3.0,0.2, r'IFMR 2: $\Delta \tau_{\rm life}$ = '+str(delta_t_1)+' Myr', fontsize=14)



plt.legend(loc=2)

plt.xlabel("ZAMS Mass")
plt.ylabel("WD Mass")

plt.ylim(0.1,1.3)
plt.xlim(1.0,7.0)

plt.show()
#plt.savefig("../figures/likelihood_test_features1_err001.pdf")

# %% [markdown]
# ### WD mass error = 0.03

# %%
p_true_2 = np.array([0.1, 0.1, 0.38, 0.05])
N_sys_2 = 20
DWD_2 = create_mock_data_test(p_true_2, N_sys_2, error=0.03)

# %%
N_pts = 30
x = np.linspace(0.02, 0.2, N_pts)
y = np.linspace(0.1, 1.0, N_pts)
theta1, theta2 = np.meshgrid(x, y)

b_int = p_true_2[0] * np.ones([N_pts, N_pts])
theta3 = p_true_2[3] * np.ones([N_pts, N_pts])

like_i = np.array([])
for i in np.arange(len(b_int.flatten())):
    p_test = p_true_2.copy()
    p_test[1] = theta1.flatten()[i]
    p_test[2] = theta2.flatten()[i]

    ln_like = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
    like_i = np.append(like_i, np.sum(ln_like))

#print DWD_2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-28eef8bfacc1> in <module>()
#      13     p_test[2] = theta2.flatten()[i]
#      14
# ---> 15     ln_like = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
#      16     like_i = np.append(like_i, np.sum(ln_like))
#      17
#
# <ipython-input-7-3dd1222a2ff8> in ln_likelihood_test(p, MESA_tcool, DWD)
#      46         # Calculate MS lifetimes
#      47         dist_time1 = func_lifetime(dist_zams1)
# ---> 48         dist_time2 = func_lifetime(dist_zams2)
#      49
#      50
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/polyint.pyc in __call__(self, x)
#      52         """
#      53         x, x_shape = self._prepare_x(x)
# ---> 54         y = self._evaluate(x)
#      55         return self._finish_y(y, x_shape)
#      56
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     447         x_new = asarray(x_new)
#     448         out_of_bounds = self._check_bounds(x_new)
# --> 449         y_new = self._call(self, x_new)
#     450         if len(y_new) > 0:
#     451             y_new[out_of_bounds] = self.fill_value
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpolate.pyc in _call_linear(self, x_new)
#     409         x_lo = self.x[lo]
#     410         x_hi = self.x[hi]
# --> 411         y_lo = self._y[lo]
#     412         y_hi = self._y[hi]
#     413
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()

like_temp = np.copy(like_i)
like_temp[np.where(like_i < max(like_i)-30.0)] = max(like_i)-30.0
like_temp = like_temp.reshape(N_pts, N_pts)

p = ax.pcolor(theta1, theta2, like_temp, cmap='RdBu', vmin=np.min(like_temp), vmax=np.max(like_temp))
cb = fig.colorbar(p, ax=ax)

ax.axvline(p_true_2[1], color='k')
ax.axhline(p_true_2[2], color='k')

x_max = theta1.flatten()[np.argmax(like_temp)]
y_max = theta2.flatten()[np.argmax(like_temp)]
    
plt.xlim(0.02,0.20)    
plt.ylim(0.1,1.0)    

plt.xlabel(r'$\theta_1$')
plt.ylabel(r'$\theta_2$')
    
ax.scatter(x_max, y_max, color='c')
    
#plt.savefig('../figures/likelihood_test_2D_N20_err03.pdf')
plt.show()

# %%
like_i_2 = np.array([])
for tmp in y:
    p_test = p_true_2.copy()
    p_test[2] = tmp

    ln_like_2 = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
    like_i_2 = np.append(like_i_2, np.sum(ln_like_2))

# %%
plt.plot(y, like_i_2)
plt.scatter(y, like_i_2)

plt.axvline(p_true_2[2], color='k')

plt.ylim(-400,-380)

plt.ylabel('Likelihood')
plt.xlabel(r'$\theta_2$')

#plt.savefig('../figures/likelihood_test_N20_err03.pdf')
plt.show()

# %% [markdown]
# ### Now for WD mass error = 0.001

# %%
p_true_2 = np.array([0.1, 0.1, 0.38, 0.05])
N_sys_2 = 20
DWD_2 = create_mock_data_test(p_true_2, N_sys_2, error=0.001)

# %%
N_pts = 30
x = np.linspace(0.02, 0.2, N_pts)
y = np.linspace(0.1, 1.0, N_pts)
theta1, theta2 = np.meshgrid(x, y)

b_int = p_true_2[0] * np.ones([N_pts, N_pts])
theta3 = p_true_2[3] * np.ones([N_pts, N_pts])

like_i = np.array([])
for i in np.arange(len(b_int.flatten())):
    p_test = p_true_2.copy()
    p_test[1] = theta1.flatten()[i]
    p_test[2] = theta2.flatten()[i]

    ln_like = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
    like_i = np.append(like_i, np.sum(ln_like))

# %%
fig, ax = plt.subplots()

like_temp = np.copy(like_i)
like_temp[np.where(like_i < max(like_i)-30.0)] = max(like_i)-30.0
like_temp = like_temp.reshape(N_pts, N_pts)

p = ax.pcolor(theta1, theta2, like_temp, cmap='RdBu', vmin=np.min(like_temp), vmax=np.max(like_temp))
cb = fig.colorbar(p, ax=ax)

ax.axvline(p_true_2[1], color='k')
ax.axhline(p_true_2[2], color='k')

x_max = theta1.flatten()[np.argmax(like_temp)]
y_max = theta2.flatten()[np.argmax(like_temp)]
    
plt.xlim(0.02,0.20)    
plt.ylim(0.1,1.0)    
    
ax.scatter(x_max, y_max, color='c')
    
    
#plt.savefig('../figures/likelihood_test_2D_N20_err001.pdf')
plt.show()

# %%
like_i_2 = np.array([])
for tmp in y:
    p_test = p_true_2.copy()
    p_test[2] = tmp

    ln_like_2 = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
    like_i_2 = np.append(like_i_2, np.sum(ln_like_2))

# %%
plt.plot(y, like_i_2)
plt.scatter(y, like_i_2)

plt.axvline(p_true_2[2], color='k')

plt.ylim(-380,-350)

plt.ylabel('Likelihood')
plt.xlabel(r'$\theta_2$')

#plt.savefig('../figures/likelihood_test_N20_err001.pdf')
plt.show()

# %%
p_test = np.array([0.10, 0.10, 0.30, 0.10])
print ln_posterior(p_test, MESA_tcool, DWD_1)
print ln_posterior(p_true_1, MESA_tcool, DWD_1)

print ln_likelihood(p_test, MESA_tcool, DWD_1)
print ln_likelihood(p_true_1, MESA_tcool, DWD_1)
# Out:
# -0.39828766981
# -0.0363177532338
# [ -1.08732304e-03  -2.83160019e-01  -5.80072657e-11  -4.14997405e-03
#   -2.87096237e-04  -4.28821606e-02  -7.65066522e-02  -4.84469163e-02
#   -3.71719093e-02  -2.39566705e-02]
# [ -8.26954044e-06  -7.24609497e-03  -3.27240320e-03  -6.12480679e-05
#   -1.94987217e-03  -9.08120210e-03  -1.60100664e-06  -1.25304365e-04
#   -2.42625163e-05  -2.02928655e-03]

# %%
ndim = 4

samples = sampler_2.chain[:,:,:].reshape((-1, ndim))
DWD = DWD_2

M_zams_temp = np.linspace(0.,7.,50)


#for b1, th1 in samples[np.random.randint(len(samples),size=20)]:
for bt1, th1, th2, th3 in samples[np.random.randint(len(samples),size=50)]:

    m1 = np.tan(th1)
    m2 = np.tan(th2)
    m3 = np.tan(th3)
    b1 = bt1 / np.cos(th1)
    b2 = (m1-m2)*2.0 + b1
    b3 = (m2-m3)*4.0 + b2
    
    M_wd_temp = np.array([])

#    M_wd_temp = m1*M_zams_temp+b1
    
    for m in M_zams_temp:
    
        if m < 2.0:
            M_wd_temp = np.append(M_wd_temp, m1*m+b1)
        
        elif m < 4.0:
            M_wd_temp = np.append(M_wd_temp, m2*m+b2)

        else:
            M_wd_temp = np.append(M_wd_temp, m3*m+b3)


    
#    plt.plot(M_zams_temp, M_wd_temp, color="k", alpha=0.15)

    
# Plot true values
bt1_true, th1_true, th2_true, th3_true = p_true_2
m1 = np.tan(th1_true)
m2 = np.tan(th2_true)
m3 = np.tan(th3_true)
b1 = bt1_true / np.cos(th1_true)
b2 = (m1-m2)*2.0 + b1
b3 = (m2-m3)*4.0 + b2
    
#print m1, m2, m3
    
M_wd_temp = np.array([])
#M_wd_temp = m1*M_zams_temp+b1
for m in M_zams_temp:
    
    if m < 2.0:
        M_wd_temp = np.append(M_wd_temp, m1*m+b1)
        
    elif m < 4.0:
        M_wd_temp = np.append(M_wd_temp, m2*m+b2)

    else:
        M_wd_temp = np.append(M_wd_temp, m3*m+b3)


    
plt.plot(M_zams_temp, M_wd_temp, "-r")


Mzams1_true = get_mzams(p_true_2, DWD["m1_wd"])
Mzams2_true = get_mzams(p_true_2, DWD["m2_wd"])


#plt.plot(Mzams1_true, DWD["m1_wd"], "o", alpha=0.5)
#plt.plot(Mzams2_true, DWD["m2_wd"], "o", alpha=0.5)

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 14}

plt.rc('font', **font)

plt.xlabel("Initial Mass (M$_{\odot}$)")
plt.ylabel("Final Mass (M$_{\odot}$)")

plt.gcf().subplots_adjust(bottom=0.15)


plt.ylim(0.0,1.4)


#plt.savefig('../figures/samples_2_input.pdf')
plt.show()
#plt.savefig('../figures/samples_2.pdf')

# %% [markdown]
# ### Plot chains to check convergence

# %%
for i in range(sampler_1.dim):
    plt.figure()
    for chain in sampler_1.chain[...,i]:
        plt.plot(chain, alpha=0.25, color='k', drawstyle='steps')

# %%
for i in np.arange(len(DWD_2)):
    print i, DWD_2["m1_wd"][i], DWD_2["m2_wd"][i]
# Out:
# 0 0.516216107179 0.486804105185
# 1 0.487398451747 0.494678126587
# 2 0.512321687737 0.522945849659
# 3 0.451237465702 0.46326612754
# 4 0.487896511007 0.504097069405
# 5 0.474965909049 0.506411909543
# 6 0.453561653445 0.51554657098
# 7 0.491573479403 0.551873773486
# 8 0.525928544834 0.533163985377
# 9 0.502736690861 0.528567777789
# 10 0.563375246223 0.527432901252
# 11 0.506006145861 0.509472937752
# 12 0.523604174007 0.48737700971
# 13 0.545718689059 0.482081059518
# 14 0.535850020517 0.492599616178
# 15 0.515898043099 0.503751951833
# 16 0.503218908149 0.4789898673
# 17 0.494360407663 0.478318069361
# 18 0.508899265777 0.525637467382
# 19 0.456992841315 0.460506787896
# 20 0.559792855639 0.558886294887
# 21 0.551807330472 0.564096013517
# 22 0.502802686414 0.51561916989
# 23 0.598187468567 0.482115514875
# 24 0.499153410882 0.501565158922
# 25 0.563622510222 0.46530996354
# 26 0.578988853303 0.526096105742
# 27 0.529244829417 0.496777517812
# 28 0.575107052979 0.428226984577
# 29 0.524334555952 0.51945685678
# 30 0.584357352969 0.532809980669
# 31 0.542000935918 0.455128278202
# 32 0.556167997558 0.472006124215
# 33 0.578629865702 0.528298009292
# 34 0.575001605035 0.509595950828
# 35 0.541559623638 0.443560202645
# 36 0.538600657995 0.529084429278
# 37 0.521996138509 0.515963743535
# 38 0.525347139355 0.494285116698
# 39 0.54892012235 0.518195192719
# 40 0.606757827386 0.528681866037
# 41 0.546716726974 0.475424127245
# 42 0.59138108001 0.518976461468
# 43 0.560440393248 0.571564681674
# 44 0.562767829408 0.469893699484
# 45 0.65761496178 0.502071703607
# 46 0.632086600216 0.567694249829
# 47 0.586298874832 0.487492647332
# 48 0.5719363324 0.545876007133
# 49 0.532689813551 0.467567060746
# 50 0.603544902764 0.454955186276
# 51 0.552748797776 0.448190949393
# 52 0.643739611231 0.483657040685
# 53 0.623297787088 0.483500488221
# 54 0.561996486982 0.475790541342
# 55 0.608562409302 0.487810359696
# 56 0.598442752454 0.478610913192
# 57 0.608702779168 0.524604511256
# 58 0.64955393332 0.520556250745
# 59 0.659265889984 0.505732345887
# 60 0.647663786402 0.487917055735
# 61 0.596626854527 0.50952458162
# 62 0.59014616167 0.515519138423
# 63 0.608664593084 0.489351317116
# 64 0.634765535486 0.497089122664
# 65 0.691969443626 0.490701418428
# 66 0.631997383575 0.466853228168
# 67 0.615712232153 0.458203469616
# 68 0.654412481397 0.515037754845
# 69 0.679455648159 0.538928935462
# 70 0.63618345256 0.512436139383
# 71 0.62558186443 0.511219851022
# 72 0.590365707967 0.513844465675
# 73 0.658647969395 0.508392146434
# 74 0.650357325982 0.489690519231
# 75 0.660413338311 0.456584482456
# 76 0.641028693822 0.436576616219
# 77 0.633626277321 0.54161064809
# 78 0.699620031334 0.533599565185
# 79 0.632612862092 0.543400422381
# 80 0.66046555916 0.528136208099
# 81 0.684926967067 0.532786678607
# 82 0.676970906389 0.525012850707
# 83 0.690930428085 0.459884176295
# 84 0.68302784172 0.515269980998
# 85 0.634143481261 0.483529688733
# 86 0.690334921234 0.457714118096
# 87 0.672668708173 0.512541113964
# 88 0.657965270432 0.452780870006
# 89 0.656565213312 0.44527868536
# 90 0.707541990251 0.501448385705
# 91 0.679381459615 0.463454769215
# 92 0.715100548995 0.487807141557
# 93 0.690746191054 0.458145765714
# 94 0.646363518757 0.50919236035
# 95 0.709335540928 0.511779139321
# 96 0.704360818538 0.506581798862
# 97 0.693352584991 0.443051321527
# 98 0.679892229234 0.479490770185
# 99 0.661963438077 0.494145020694

# %%
p_true = p_true_4
DWD = DWD_4

func_lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=7.0)    
func_lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)

#p_test = np.copy(p_true)
#p_test[1] = 0.13
#p_test[2] = 0.58

N_samp = 800000
hist_bins = 500

index = 2


# Determine their ZAMS masses
M1_zams = get_mzams(p_true, DWD["m1_wd"])
M2_zams = get_mzams(p_true, DWD["m2_wd"])

# Get the Main Sequence lifetimes from these ZAMS masses
M1_lifetime = func_lifetime(M1_zams)
M2_lifetime = func_lifetime(M2_zams)
delta_MS_lifetime = M2_lifetime-M1_lifetime



dist_wd1 = np.array([])
dist_wd2 = np.array([])
dist_wd1 = np.random.normal(DWD["m1_wd"][index], DWD["m1_wd_err"][index], N_samp)
dist_wd2 = np.random.normal(DWD["m2_wd"][index], DWD["m2_wd_err"][index], N_samp)

#dist_zams1 = get_mzams(p_test, dist_wd1)
#dist_zams2 = get_mzams(p_test, dist_wd2)
dist_zams1 = get_mzams(p_true, dist_wd1)
dist_zams2 = get_mzams(p_true, dist_wd2)

dist_life1 = lifetime(MESA_tcool, dist_zams1)
dist_life2 = lifetime(MESA_tcool, dist_zams2)

delta_cool = DWD["age2"][index] - DWD["age1"][index]
delta_cool_err = np.sqrt(DWD["age1_err"][index]*DWD["age1_err"][index] + DWD["age2_err"][index]*DWD["age2_err"][index])


center_zams = get_mzams(p_test, [DWD["m1_wd"][index],DWD["m2_wd"][index]])
center_cool = lifetime(MESA_tcool, center_zams)


plt.figure(figsize=(16,12))

plt.subplot(4,2,1)
n, bins, patches = plt.hist(dist_wd1, hist_bins, normed=1, histtype='stepfilled')
plt.axvline(DWD["m1_wd"][index], color='k')
plt.xlabel("WD$_1$ Mass")


plt.subplot(4,2,2)
n, bins, patches = plt.hist(dist_wd2, hist_bins, normed=1, histtype='stepfilled')
plt.axvline(DWD["m2_wd"][index], color='k')
plt.xlabel('WD$_2$ Mass')


plt.subplot(4,2,3)
n, bins, patches = plt.hist(dist_zams1, hist_bins, normed=1, histtype='stepfilled')
#plt.axvline(M1_zams[index], color='k')
plt.axvline(center_zams[0], color='k')
plt.xlabel("ZAMS$_1$ Mass")


plt.subplot(4,2,4)
n, bins, patches = plt.hist(dist_zams2, hist_bins, normed=1, histtype='stepfilled')
#plt.axvline(M2_zams[index], color='k')
plt.axvline(center_zams[1], color='k')
plt.xlabel("ZAMS$_2$ Mass")





plt.subplot(4,2,5)
n, bins, patches = plt.hist(dist_life1, hist_bins, normed=1, histtype='stepfilled')
#plt.axvline(M1_lifetime[index], color='k')
plt.axvline(center_cool[0], color='k')
plt.xlabel("Lifetime$_1$")

plt.subplot(4,2,7)
dm_zams_dt_ms1 = (get_m_wd(p_true,func_lifetime_inv(bins + 1.0e4)) - get_m_wd(p_true,func_lifetime_inv(bins))) / 1.0e4
#dm_zams_dt_ms1 = (func_lifetime_inv(bins + 1.0e4) - func_lifetime_inv(bins)) / 1.0e4
dt_ms_dm_zams1 = -1.0 / dm_zams_dt_ms1
plt.plot(bins[:hist_bins], dt_ms_dm_zams1[:hist_bins] * n)
plt.axvline(M1_lifetime[index], color='k')

tmp_x = np.linspace(0.0,6.0e8, 1000)
tmp_m1 = get_m_wd(p_true, func_lifetime_inv(tmp_x))
tmp_m2 = DWD["m1_wd"][index]
tmp_m2_e = DWD["m1_wd_err"][index]
tmp_y = 1.0/(np.sqrt(2.0*np.pi) * tmp_m2_e) * np.exp(-(tmp_m1-tmp_m2)*(tmp_m1-tmp_m2)/(2.0*tmp_m2_e*tmp_m2_e))
plt.plot(tmp_x, tmp_y)




plt.subplot(4,2,6)
n, bins, patches = plt.hist(dist_life2, hist_bins, normed=1, histtype='stepfilled')
#plt.axvline(M2_lifetime[index], color='k')
plt.axvline(center_cool[1], color='k')
plt.xlabel("Lifetime$_2$")
plt.xlim(0.0,2.0e9)


plt.subplot(4,2,8)
dm_zams_dt_ms2 = (get_m_wd(p_true,func_lifetime_inv(bins + 1.0e4)) - get_m_wd(p_true,func_lifetime_inv(bins))) / 1.0e4
dt_ms_dm_zams2 = -1.0 / dm_zams_dt_ms2
plt.plot(bins[:hist_bins], dt_ms_dm_zams2[:hist_bins] * n)
plt.axvline(M2_lifetime[index], color='k')
plt.xlim(0.0,2.0e9)

tmp_x = np.linspace(0.0,2.0e9, 1000)
tmp_m1 = get_m_wd(p_true, func_lifetime_inv(tmp_x))
tmp_m2 = DWD["m2_wd"][index]
tmp_m2_e = DWD["m2_wd_err"][index]
tmp_y = 1.0/(np.sqrt(2.0*np.pi) * tmp_m2_e) * np.exp(-(tmp_m1-tmp_m2)*(tmp_m1-tmp_m2)/(2.0*tmp_m2_e*tmp_m2_e))
plt.plot(tmp_x, tmp_y)

#print bins[np.argmax(n)]


#bins_m_wd = func_lifetime_inv(bins) * np.tan(p_true[1])
#dt_ms_dm_zams1 = (lifetime(MESA_tcool,get_mzams(p_true,bins_m_wd+0.001)) - bins) / (0.001)

plt.show()


plt.figure(figsize=(16,4))

plt.subplot(1,2,1)
n, bins, patches = plt.hist(dist_life1 - dist_life2, hist_bins, normed=1, histtype='stepfilled')
plt.axvline(M1_lifetime[index] - M2_lifetime[index], color='k')
plt.xlabel("Lifetime difference")
plt.xlim(-1.5e9,0.0e9)
plt.ylim(0.0,1.1*max(n))
n_old = n

plt.subplot(1,2,2)
deriv1 = -1.0 / (get_m_wd(p_true,func_lifetime_inv(dist_life1 + 1.0)) - get_m_wd(p_true,func_lifetime_inv(dist_life1)))
deriv2 = -1.0 / (get_m_wd(p_true,func_lifetime_inv(dist_life2 + 1.0)) - get_m_wd(p_true,func_lifetime_inv(dist_life2)))

# Find average delta cool
delta_time = dist_life1-dist_life2
avg_delta_cool = np.sum(delta_time)/(N_samp+0.0)
# Find scipy optimize maximum position at "xmin"
jacobian = deriv1*deriv2
result = opt.minimize(temp_func, avg_delta_cool, args=(delta_time, delta_cool_err, jacobian), method='Powell', tol=1.0e-5)
xmin = result.x


total_weight = np.sum(deriv1*deriv2)
n, bins, patches = plt.hist(dist_life1 - dist_life2, hist_bins, weights=deriv1*deriv2*(N_samp+0.0)/total_weight, histtype='stepfilled')
#plt.plot(bins[:hist_bins], 2.0e8*max(n) * mlab.normpdf(bins[:hist_bins],delta_cool,delta_cool_err))
#plt.plot(bins[:hist_bins], 2.0e8*max(n) * mlab.normpdf(bins[:hist_bins],avg_delta_cool,delta_cool_err))
plt.plot(bins[:hist_bins], 3.0e8*max(n) * mlab.normpdf(bins[:hist_bins],xmin,delta_cool_err), color='r')
plt.plot(bins[:hist_bins], 3.0e8*max(n) * mlab.normpdf(bins[:hist_bins],M1_lifetime[index] - M2_lifetime[index],delta_cool_err), color='k')

plt.axvline(M1_lifetime[index] - M2_lifetime[index], color='k')
plt.axvline(xmin, color='r')
plt.xlabel("Lifetime difference")
plt.xlim(-1.5e9,0.0e9)
#plt.ylim(0.0,1.1*max(n_old))


plt.show()

# %%
print DWD_2

print p_true_2
# Out:
# [(0.5, 0.03, 0.5, 0.03, 10000000.0, 1000000.0, 10000000.0, 1000000.0)
#  (0.5105263157894737, 0.03, 0.5, 0.03, 288410861.7269211, 28841086.17269211, 10000000.0, 1000000.0)
#  (0.5210526315789473, 0.03, 0.5, 0.03, 451678602.3051543, 45167860.230515435, 10000000.0, 1000000.0)
#  (0.531578947368421, 0.03, 0.5, 0.03, 599722070.8497448, 59972207.08497448, 10000000.0, 1000000.0)
#  (0.5421052631578948, 0.03, 0.5, 0.03, 747765539.3943355, 74776553.93943356, 10000000.0, 1000000.0)
#  (0.5526315789473684, 0.03, 0.5, 0.03, 895809007.9389253, 89580900.79389253, 10000000.0, 1000000.0)
#  (0.5631578947368421, 0.03, 0.5, 0.03, 1041554875.4504788, 104155487.54504788, 10000000.0, 1000000.0)
#  (0.5736842105263158, 0.03, 0.5, 0.03, 1117173062.791436, 111717306.2791436, 10000000.0, 1000000.0)
#  (0.5842105263157895, 0.03, 0.5, 0.03, 1192791250.1323934, 119279125.01323934, 10000000.0, 1000000.0)
#  (0.5947368421052631, 0.03, 0.5, 0.03, 1268409437.47335, 126840943.74733502, 10000000.0, 1000000.0)
#  (0.6052631578947368, 0.03, 0.5, 0.03, 1344027624.8143072, 134402762.48143074, 10000000.0, 1000000.0)
#  (0.6157894736842104, 0.03, 0.5, 0.03, 1413022937.8661976, 141302293.78661975, 10000000.0, 1000000.0)
#  (0.6263157894736842, 0.03, 0.5, 0.03, 1451893770.6812704, 145189377.06812704, 10000000.0, 1000000.0)
#  (0.6368421052631579, 0.03, 0.5, 0.03, 1490764603.4963431, 149076460.34963432, 10000000.0, 1000000.0)
#  (0.6473684210526316, 0.03, 0.5, 0.03, 1529635436.311416, 152963543.6311416, 10000000.0, 1000000.0)
#  (0.6578947368421052, 0.03, 0.5, 0.03, 1568506269.1264882, 156850626.91264883, 10000000.0, 1000000.0)
#  (0.6684210526315789, 0.03, 0.5, 0.03, 1610789526.859628, 161078952.6859628, 10000000.0, 1000000.0)
#  (0.6789473684210526, 0.03, 0.5, 0.03, 1660040967.6753693, 166004096.76753694, 10000000.0, 1000000.0)
#  (0.6894736842105262, 0.03, 0.5, 0.03, 1709292408.4911103, 170929240.84911105, 10000000.0, 1000000.0)
#  (0.7, 0.03, 0.5, 0.03, 1758543849.3068519, 175854384.9306852, 10000000.0, 1000000.0)]
# [ 0.1   0.25]

# %%
p_true = p_true_2
DWD = DWD_2

func_lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=7.0)    
func_lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)

p_test = np.copy(p_true)
p_test[1] = 0.13
p_test[2] = 0.58

N_samp = 800000
hist_bins = 500

index = 16


# Determine their ZAMS masses
M1_zams = get_mzams(p_true, DWD["m1_wd"])
M2_zams = get_mzams(p_true, DWD["m2_wd"])

# Get the Main Sequence lifetimes from these ZAMS masses
M1_lifetime = lifetime(MESA_tcool, M1_zams)
M2_lifetime = lifetime(MESA_tcool, M2_zams)
delta_MS_lifetime = M2_lifetime-M1_lifetime



# Create distributions
# WD 1
dist_wd1 = np.random.normal(DWD["m1_wd"][index], DWD["m1_wd_err"][index], N_samp)
dist_zams1 = get_mzams(p_test, dist_wd1)
dist_life1 = lifetime(MESA_tcool, dist_zams1)

# WD 2
dist_wd2 = np.random.normal(DWD["m2_wd"][index], DWD["m2_wd_err"][index], N_samp)
dist_zams2 = get_mzams(p_test, dist_wd2)
dist_life2 = lifetime(MESA_tcool, dist_zams2)

dist_delta_t_MS = dist_life2 - dist_life1

# Cooling age difference
delta_cool = DWD["age2"][index] - DWD["age1"][index]
delta_cool_err = np.sqrt(DWD["age1_err"][index]*DWD["age1_err"][index] + DWD["age2_err"][index]*DWD["age2_err"][index])
dist_delta_cool = np.random.normal(delta_cool, delta_cool_err, N_samp)

center_zams = get_mzams(p_test, [DWD["m1_wd"][index],DWD["m2_wd"][index]])
center_cool = lifetime(MESA_tcool, center_zams)



# PLOTS
plt.figure(figsize=(16,4))

plt.subplot(1,2,1)

deriv1 = -1.0 / (func_lifetime_inv(dist_life1 + 1.0) - func_lifetime_inv(dist_life1))
deriv2 = -1.0 / (func_lifetime_inv(dist_life2 + 1.0) - func_lifetime_inv(dist_life2))
total_weight = np.sum(deriv1*deriv2)
n, bins, patches = plt.hist(dist_life1 - dist_life2, hist_bins, weights=deriv1*deriv2*(N_samp+0.0)/total_weight, histtype='stepfilled')
#n, bins, patches = plt.hist(dist_delta_t_MS, hist_bins, normed=1, histtype='stepfilled')

#plt.axvline(DWD["m1_wd"][index], color='k')
plt.xlabel(r"$\Delta \tau$")
plt.xlim(-4.0e8,4.0e8)

# "Observed" cooling age difference
n, bins, patches = plt.hist(dist_delta_cool, bins, weights = 0.1 * np.ones(len(dist_delta_cool)), histtype='step', color='r')
#plt.plot(bins[:hist_bins], 1.0e9*mlab.normpdf(bins[:hist_bins],delta_cool,delta_cool_err))
#plt.plot(bins[:hist_bins], 1.0e5 * mlab.normpdf(bins[:hist_bins],M2_lifetime[index] - M1_lifetime[index],delta_cool_err), color='k')

plt.text(-3.5e8, 7.0e3, "Incorrect Model", fontsize=14)




# True Parameters

# WD 1
dist_zams1 = get_mzams(p_true, dist_wd1)
dist_life1 = lifetime(MESA_tcool, dist_zams1)

# WD 2
dist_zams2 = get_mzams(p_true, dist_wd2)
dist_life2 = lifetime(MESA_tcool, dist_zams2)

dist_delta_t_MS = dist_life2 - dist_life1



plt.subplot(1,2,2)
deriv1 = -1.0 / (func_lifetime_inv(dist_life1 + 1.0) - func_lifetime_inv(dist_life1))
deriv2 = -1.0 / (func_lifetime_inv(dist_life2 + 1.0) - func_lifetime_inv(dist_life2))
total_weight = np.sum(deriv1*deriv2)
n, bins, patches = plt.hist(dist_life1 - dist_life2, hist_bins, weights=deriv1*deriv2*(N_samp+0.0)/total_weight, histtype='stepfilled')
#n, bins, patches = plt.hist(dist_delta_t_MS, hist_bins, normed=1, histtype='stepfilled')


#plt.axvline(DWD["m1_wd"][index], color='k')
plt.xlabel(r"$\Delta \tau$")
plt.xlim(-4.0e8,4.0e8)

# "Observed" cooling age difference
n, bins, patches = plt.hist(dist_delta_cool, bins, histtype='step', weights = 0.1 * np.ones(len(dist_delta_cool)), color='r')
#plt.plot(bins[:hist_bins], 0.15 * mlab.normpdf(bins[:hist_bins],M2_lifetime[index] - M1_lifetime[index],delta_cool_err), color='k')

plt.text(-3.5e8, 7.0e3, "Input Model", fontsize=14)








plt.show()

# %%
# Calculate likelihood function
def ln_likelihood_test_2(p, MESA_tcool, DWD):
    

    # Define lifetime interpolation functions
    func_lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=1.0e7)    
    func_lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)
    
    
    # Number of samples for our Monte Carlo integration
#    N_samp = 4
    N_samp = 2000

    # Limit the WD mass to be confined within this range
    wd_lower = 0.5    # Lowest allowed WD mass
    wd_upper = 1.4    # Highest allowed WD mass
    # First determine upper and lower
    zams_limits = np.array([min(MESA_tcool["name"]), max(MESA_tcool["name"])])
    wd_limits = get_m_wd(p, zams_limits)
    t_limits = func_lifetime(zams_limits)
    lower = wd_limits[0]
    upper = wd_limits[1]


    # Create probability array
    P_sys = np.array([])
    dist_wd1 = np.array([])
    dist_wd2 = np.array([])
    statistic = np.array([])
       
    # Calculate each system individually
    for sys in DWD:

        # Define array of cooling age differences
        delta_cool = sys["age2"] - sys["age1"]
        delta_cool_err = np.sqrt(sys["age1_err"]*sys["age1_err"] + sys["age2_err"]*sys["age2_err"])
                
        # WD 1
        dist_wd1 = truncnorm.rvs((lower - sys["m1_wd"]) / sys["m1_wd_err"], (upper - sys["m1_wd"]) / sys["m1_wd_err"], loc=sys["m1_wd"], scale=sys["m1_wd_err"], size=N_samp)
        dist_zams1 = get_mzams(p, dist_wd1)
        dist_time1 = func_lifetime(dist_zams1)

        # Get distribution of cooling age differences
        dist_delta_cool = np.random.normal(delta_cool, delta_cool_err, N_samp)
        
        # WD 2
        dist_time2 = np.array([])
        dist_time2 = dist_time1 - dist_delta_cool
        dist_zams2 = func_lifetime_inv(dist_time2)
        dist_wd2 = get_m_wd(p_test, dist_zams2)
        
        # Now get the probability
        coeff = 1./(sys["m2_wd_err"] * np.sqrt(2. * np.pi))
        argument = np.exp(-(dist_wd2 - sys["m2_wd"])*(dist_wd2 - sys["m2_wd"])/(2. * sys["m2_wd_err"]*sys["m2_wd_err"]))
        P_sys = np.append(P_sys, np.sum(coeff * argument) / N_samp)
                
        
    ln_P_sys = np.log(P_sys)            
    ln_P_sys[np.isnan(ln_P_sys)] = -np.inf
    
    return ln_P_sys
#    return (ln_P_sys, statistic)

# %%
p_true_2 = np.array([0.1, 0.1, 0.38, 0.05])
N_sys_2 = 100
DWD_2 = create_mock_data_test(p_true_2, N_sys_2, error=0.03)

p_test = np.copy(p_true_2)


print ln_likelihood_test(p_test, MESA_tcool, DWD_2)
# Out:
# [-19.59532867 -19.32583086 -19.32444476 -19.60708568 -19.50460413
#  -19.87754671 -20.95785114 -20.72220965 -19.35445226 -19.79725604
#  -19.24926886 -19.46120726 -19.35056984 -19.66871625 -19.37809894
#  -19.41132868 -19.36841432 -19.46981852 -19.95955753 -19.79676885
#  -19.78650324 -20.49526043 -20.58177572 -20.57889752 -19.96951629
#  -19.84510885 -19.22210229 -19.34309328 -22.19410599 -20.00059159
#  -19.31401024 -19.69051261 -19.4252248  -19.28303782 -19.26735777
#  -19.75011146 -20.18560967 -20.08827079 -19.77064409 -19.75221227
#  -19.25843489 -19.35779393 -19.24199446 -21.32847307 -19.41055962
#  -19.4531384  -19.31656932 -19.29542126 -20.7879847  -19.47699013
#  -19.66924451 -19.39904385 -19.95124357 -19.31337978 -19.39217109
#  -19.31411137 -19.2976613  -19.88370839 -19.25930557 -19.38234871
#  -19.3504284  -19.67067893 -19.75744679 -19.24897256 -19.24107664
#  -20.44829639 -19.38421073 -19.66558768 -19.17303421 -19.347554
#  -19.19699423 -19.37949285 -20.58733186 -19.18947155 -19.52200182
#  -20.22722904 -19.99004054 -20.04060256 -19.18087455 -20.65822304
#  -20.03243519 -19.09496043 -19.8763115  -20.89358802 -19.56684438
#  -19.33845331 -20.70152604 -19.1998635  -19.9839846  -19.7638621
#  -19.19097175 -20.45301327 -19.96861646 -20.3493545  -19.44899183
#  -19.66798436 -19.30367778 -20.44556675 -19.27380742 -19.38756103]

# %%
N_pts = 50
x = np.linspace(0.02, 0.25, N_pts)
y = np.linspace(0.1, 1.0, N_pts)
theta1, theta2 = np.meshgrid(x, y)

b_int = p_true_2[0] * np.ones([N_pts, N_pts])
theta3 = p_true_2[3] * np.ones([N_pts, N_pts])

like_i = np.array([])
for i in np.arange(len(b_int.flatten())):
    p_test = p_true_2.copy()
    p_test[1] = theta1.flatten()[i]
    p_test[2] = theta2.flatten()[i]

    ln_like = ln_likelihood_test(p_test, MESA_tcool, DWD_2)
    like_i = np.append(like_i, np.sum(ln_like))

#print DWD_2

# %%
fig, ax = plt.subplots()

like_temp = np.copy(like_i)
like_temp[np.where(like_i < max(like_i)-30.0)] = max(like_i)-30.0
like_temp = like_temp.reshape(N_pts, N_pts)

p = ax.pcolor(theta1, theta2, like_temp, cmap='RdBu', vmin=np.min(like_temp), vmax=np.max(like_temp))
cb = fig.colorbar(p, ax=ax)

ax.axvline(p_true_2[1], color='k')
ax.axhline(p_true_2[2], color='k')

x_max = theta1.flatten()[np.argmax(like_temp)]
y_max = theta2.flatten()[np.argmax(like_temp)]
    
plt.xlim(0.02,0.25)    
plt.ylim(0.1,1.0)    

plt.xlabel(r'$\theta_1$')
plt.ylabel(r'$\theta_2$')
    
ax.scatter(x_max, y_max, color='c')
    
print r"Highest likelihood: $\theta_1=$", x_max, r'$\theta_2=$', y_max
    
#plt.savefig('../figures/likelihood_test_2D_N20_err03.pdf')
plt.show()
# Out:
# Highest likelihood: $\theta_1=$ 0.132653061224 $\theta_2=$ 0.577551020408

# %% [markdown]
# ### Let's try to repeat the exercise with a simpler model, using only two parameters for the IFMR

# %%
# Function to return M_zams from M_wd using model
def get_mzams_2(p, m_wd):
    bt, th = p
    
    m = np.tan(th)    
    b = bt / np.cos(th)
    
    return 1./m*(m_wd-b)
    

# Function to return M_zams from M_wd using model
def get_m_wd_2(p, m_zams):
    bt, th = p
    
    m = np.tan(th)
    b = bt / np.cos(th)
    
    return m*m_zams + b

# %%
p_true_2 = np.array([0.1, 0.25])
N_sys_2 = 20
DWD_2 = create_mock_data_test(p_true_2, N_sys_2)

print DWD_2
# Out:
# [(0.5, 0.03, 0.5, 0.03, 10000000.0, 1000000.0, 10000000.0, 1000000.0)
#  (0.5105263157894737, 0.03, 0.5, 0.03, 288410861.7269211, 28841086.17269211, 10000000.0, 1000000.0)
#  (0.5210526315789473, 0.03, 0.5, 0.03, 451678602.3051543, 45167860.230515435, 10000000.0, 1000000.0)
#  (0.531578947368421, 0.03, 0.5, 0.03, 599722070.8497448, 59972207.08497448, 10000000.0, 1000000.0)
#  (0.5421052631578948, 0.03, 0.5, 0.03, 747765539.3943355, 74776553.93943356, 10000000.0, 1000000.0)
#  (0.5526315789473684, 0.03, 0.5, 0.03, 895809007.9389253, 89580900.79389253, 10000000.0, 1000000.0)
#  (0.5631578947368421, 0.03, 0.5, 0.03, 1041554875.4504788, 104155487.54504788, 10000000.0, 1000000.0)
#  (0.5736842105263158, 0.03, 0.5, 0.03, 1117173062.791436, 111717306.2791436, 10000000.0, 1000000.0)
#  (0.5842105263157895, 0.03, 0.5, 0.03, 1192791250.1323934, 119279125.01323934, 10000000.0, 1000000.0)
#  (0.5947368421052631, 0.03, 0.5, 0.03, 1268409437.47335, 126840943.74733502, 10000000.0, 1000000.0)
#  (0.6052631578947368, 0.03, 0.5, 0.03, 1344027624.8143072, 134402762.48143074, 10000000.0, 1000000.0)
#  (0.6157894736842104, 0.03, 0.5, 0.03, 1413022937.8661976, 141302293.78661975, 10000000.0, 1000000.0)
#  (0.6263157894736842, 0.03, 0.5, 0.03, 1451893770.6812704, 145189377.06812704, 10000000.0, 1000000.0)
#  (0.6368421052631579, 0.03, 0.5, 0.03, 1490764603.4963431, 149076460.34963432, 10000000.0, 1000000.0)
#  (0.6473684210526316, 0.03, 0.5, 0.03, 1529635436.311416, 152963543.6311416, 10000000.0, 1000000.0)
#  (0.6578947368421052, 0.03, 0.5, 0.03, 1568506269.1264882, 156850626.91264883, 10000000.0, 1000000.0)
#  (0.6684210526315789, 0.03, 0.5, 0.03, 1610789526.859628, 161078952.6859628, 10000000.0, 1000000.0)
#  (0.6789473684210526, 0.03, 0.5, 0.03, 1660040967.6753693, 166004096.76753694, 10000000.0, 1000000.0)
#  (0.6894736842105262, 0.03, 0.5, 0.03, 1709292408.4911103, 170929240.84911105, 10000000.0, 1000000.0)
#  (0.7, 0.03, 0.5, 0.03, 1758543849.3068519, 175854384.9306852, 10000000.0, 1000000.0)]

# %%
p_test = np.copy(p_true_2)


print ln_likelihood_test_2(p_test, MESA_tcool, DWD_2)
# Out:
# [ 2.23796081  2.32789009  2.37194621  2.40027424  2.44008748  2.47200556
#   2.49709226  2.51079959  2.52773765  2.53846829  2.53755473  2.54837109
#   2.54994194  2.55193028  2.55139429  2.55299073  2.55187212  2.5498338
#   2.54879754  2.55002287]

# %%
N_pts = 30
x = np.linspace(0.02, 0.25, N_pts)
y = np.linspace(0.1, 0.4, N_pts)
b_int, theta = np.meshgrid(x, y)

like_i = np.array([])
for i in np.arange(len(b_int.flatten())):
    p_test = p_true_2.copy()
    p_test[0] = b_int.flatten()[i]
    p_test[1] = theta.flatten()[i]

    ln_like = ln_likelihood_test_2(p_test, MESA_tcool, DWD_2)
    like_i = np.append(like_i, np.sum(ln_like))

#print DWD_2

# %%
fig, ax = plt.subplots()

like_temp = np.copy(like_i)
like_temp[np.where(like_i < max(like_i)-30.0)] = max(like_i)-30.0
like_temp = like_temp.reshape(N_pts, N_pts)

p = ax.pcolor(b_int, theta, like_temp, cmap='RdBu', vmin=np.min(like_temp), vmax=np.max(like_temp))
cb = fig.colorbar(p, ax=ax)

ax.axvline(p_true_2[0], color='k')
ax.axhline(p_true_2[1], color='k')

x_max = b_int.flatten()[np.argmax(like_temp)]
y_max = theta.flatten()[np.argmax(like_temp)]
    
plt.xlim(0.02,0.25)    
plt.ylim(0.1,0.4)    

plt.xlabel(r'b$_t$')
plt.ylabel(r'$\theta$')
    
ax.scatter(x_max, y_max, color='c')
    
#plt.savefig('../figures/likelihood_test_2D_N20_err03.pdf')
plt.show()

# %% [markdown]
# ### Let's try creating a bunch of "observations" of the same system (N=20, but M1, M2, t_cool are constant)

# %%
def create_mock_data_test_2(p_true, N_sys=20, error=0.03):

    M1_wd = 0.7 * np.ones(N_sys)
    M2_wd = 0.5 * np.ones(N_sys)

    # Determine their ZAMS masses
    M1_zams = get_mzams(p_true, M1_wd)
    M2_zams = get_mzams(p_true, M2_wd)

    # Get the Main Sequence lifetimes from these ZAMS masses
    M1_lifetime = func_lifetime(M1_zams)
    M2_lifetime = func_lifetime(M2_zams)
    delta_MS_lifetime = M2_lifetime-M1_lifetime
        
    # System age is 1 Gyr
    age_system = np.power(10.0, 7.0)
    t1_cool = age_system + delta_MS_lifetime
    t2_cool = age_system * np.ones(N_sys) 

    # Add fake uncertainties: 10% for cooling age, 0.3 Msun in mass
    t1_cool = np.random.normal(t1_cool, 0.1*t1_cool)
    t2_cool = np.random.normal(t2_cool, 0.1*t2_cool)
    M1_wd = np.random.normal(M1_wd,error)
    M2_wd = np.random.normal(M2_wd,error)
    
    M1_wd_err = error*np.ones(N_sys)
    M2_wd_err = error*np.ones(N_sys)
    t1_cool_err = 0.1 * t1_cool
    t2_cool_err = 0.1 * t2_cool

    # Move data into structure "DWD"
    dtype=[('m1_wd','float64'),('m1_wd_err','float64'),('m2_wd','float64'),('m2_wd_err','float64'),
                      ('age1','float64'),('age1_err','float64'),('age2','float64'),('age2_err','float64')]

    DWD = np.zeros(N_sys, dtype=dtype)
    DWD["m1_wd"] = np.copy(M1_wd)
    DWD["m1_wd_err"] = np.copy(M1_wd_err)
    DWD["m2_wd"] = np.copy(M2_wd)
    DWD["m2_wd_err"] = np.copy(M2_wd_err)
    DWD["age1"] = np.copy(t1_cool)
    DWD["age1_err"] = np.copy(t1_cool_err)
    DWD["age2"] = np.copy(t2_cool)
    DWD["age2_err"] = np.copy(t2_cool_err)

    return DWD

# %%
p_true_3 = np.array([0.1, 0.1, 0.38, 0.05])
DWD_3 = create_mock_data_test_2(p_true_3, N_sys=20, error=0.03)

# %%
sqrt2pi = np.sqrt(2. * np.pi)

# Integrand for calculation in dblquad
def integrand(y, x, p, delta_cool, delta_cool_err, m1, m1_err, m2, m2_err):
        
    M_zams = np.array([func_lifetime_inv(x), func_lifetime_inv(y)])
    M_wd = get_m_wd(p, M_zams)
    
        
    # Mass 1
    tmp_m1 = M_wd[0]
    coeff1 = 1./(m1_err * sqrt2pi)
    argument1 = np.exp(-(m1 - tmp_m1)*(m1 - tmp_m1)/(2. * m1_err*m1_err))
    norm1 = coeff1 * argument1

    # Mass 2
    tmp_m2 = M_wd[1]
    coeff2 = 1./(m2_err * sqrt2pi)
    argument2 = np.exp(-(m2 - tmp_m2)*(m2 - tmp_m2)/(2. * m2_err*m2_err))
    norm2 = coeff2 * argument2

    # Delta cooling age
    tmp_d_cool = y-x
    coeff3 = 1./(delta_cool_err * sqrt2pi)
    argument3 = np.exp(-(delta_cool - tmp_d_cool)*(delta_cool - tmp_d_cool)/(2. * delta_cool_err*delta_cool_err))
    norm3 = coeff3 * argument3

    return norm1 * norm2 * norm3
    
    

# Define lifetime interpolation functions
func_lifetime = interp1d(MESA_tcool["name"],pow(10.,MESA_tcool["lifetime"]), kind='linear', bounds_error=False, fill_value=1.0e7)    
func_lifetime_inv = interp1d(pow(10.,MESA_tcool["lifetime"][::-1]),MESA_tcool["name"][::-1], kind='linear', bounds_error=False, fill_value = 0.45)

    
# Calculate likelihood function
def ln_likelihood_test_2(p, DWD):

    # Create probability array
    ln_P_sys = np.array([])


    # Integration limits
    zams_min = min(MESA_tcool["name"])
    zams_max = max(MESA_tcool["name"])
    zams_limits = np.array([zams_min, zams_max])
    wd_strict_limits = get_m_wd(p, zams_limits)
        
    # Calculate each system individually
    for sys in DWD:
        
        wd1_min = max(wd_strict_limits[0], sys["m1_wd"]-5.0*sys["m1_wd_err"])
        wd1_max = min(wd_strict_limits[1], sys["m1_wd"]+5.0*sys["m1_wd_err"])
        wd1_limits = np.array([wd1_min, wd1_max])
        t1_limits= func_lifetime(get_mzams(p, wd1_limits))
        
        t_l = t1_limits[1]
        t_h = t1_limits[0]
    
        wd2_min = max(wd_strict_limits[0], sys["m2_wd"]-5.0*sys["m2_wd_err"])
        wd2_max = min(wd_strict_limits[1], sys["m2_wd"]+5.0*sys["m2_wd_err"])
        wd2_limits = np.array([wd2_min, wd2_max])
        t2_limits= func_lifetime(get_mzams(p, wd2_limits))

        t_min = lambda x: t2_limits[1]
        t_max = lambda x: t2_limits[0]
        
        print t_l, t_h, t_min(0), t_max(0)

        
        # Define array of cooling age differences
        delta_cool = sys["age1"] - sys["age2"]
        delta_cool_err = np.sqrt(sys["age1_err"]*sys["age1_err"] + sys["age2_err"]*sys["age2_err"])
        
        my_args = (p, delta_cool,delta_cool_err,sys["m1_wd"],sys["m1_wd_err"],sys["m2_wd"],sys["m2_wd_err"])
            
        P_sys, P_sys_err = integrate.dblquad(integrand, t_l, t_h, t_min, t_max, args=my_args, epsabs=1000.0, epsrel=1000.0)

        ln_P_sys = np.append(ln_P_sys, np.log(P_sys))
                
                
    ln_P_sys[np.isnan(ln_P_sys)] = -np.inf
    
    return ln_P_sys

# %%
t_start = time.clock()

probs = ln_likelihood_test_2(p_true_3, DWD_3)

print "Elapsed time:", time.clock() - t_start, "seconds"
# Out:
# 345590274.761 735290085.002 570732981.307 1267146968.62
# 332071744.037
#  705272417.385 573977621.412 1272666660.53
# 341399294.012
#  726013210.554 515269695.806 1172794362.93
# 335193852.833
#  712277261.344 608908617.488 1326137565.18
# 369648207.033
#  800657273.611 569642252.531 1265291451.02
# 329406824.503
#  697523067.421 538557498.541 1212410928.18
# 337250029.87
#  716828677.195 654834011.738 1595021594.16
# 370137279.898
#  802019154.82 515064501.04 1172445291.27
# 374324497.767
#  813678957.967 507876811.516 1158841741.9
# 330208965.665
#  699855622.874 596248702.006 1309888932.74
# 365050226.32
#  787853652.767 525525247.161 1190240822.95
# 319869042.344
#  669788041.705 622324981.083 1343357076.71
# 371805062.739
#  806663293.297 566354342.2 1259698149.0
# 327660312.831
#  692444366.176 560418630.772 1249600481.06
# 335345063.064
#  712611970.191 534745471.066 1205926012.58
# 367516055.255
#  794720044.933 633898200.384 1386932615.3
# 372300269.738
#  808042255.728 555214573.876 1240747483.55
# 357079709.897
#  765658807.552 530811710.383 1199234007.82
# 316284704.667
#  659365105.219 485301068.607 1110180246.49
# 335586318.337
#  713145996.714 581933403.795 1286200817.25
# Elapsed time:
#  172.015177 seconds

# %%
print np.sum(probs)
# Out:
# 457.325074818

# %%
print np.sum(probs)
# Out:
# 465.883276429

# %%
p_test = np.copy(p_true_3)
p_test[1] = 0.19
p_test[2] = 0.55

probs = ln_likelihood_test_2(p_test, DWD_3)
print np.sum(probs)
# Out:
# 756801175.892 1265104696.44 1109155302.85 6030507631.57
# 734126000.215
#  1240006076.82 1113711440.29 6188606295.2
# 749198469.659
#  1257348039.73 1031273521.39 3549948980.94
# 738689366.71
#  1245863024.68 1157848104.88 9420770357.35
# 800443798.61
#  1309631057.46 1107623696.87 5977360670.34
# 729077618.809
#  1233526626.47 1063974353.06 4462721787.23
# 741671440.009
#  1249668592.01 1197833101.44 21398738094.5
# 801331007.964
#  1310536232.3 1030985386.02 3544756502.23
# 808926888.093
#  1318285924.68 1020892401.81 3362871138.12
# 730597182.337
#  1235476941.96 1144435942.8 8360072764.25
# 792102768.498
#  1301121126.23 1045674410.23 3827710981.56
# 711009395.181
#  1210336588.21 1170651382.82 10544846153.3
# 804356472.35
#  1313622960.62 1103006799.19 5817153617.31
# 725769054.729
#  1229280180.93 1094671847.95 5527929538.78
# 738907415.699
#  1246142884.2 1058621487.87 4276976548.91
# 796575939.37
#  1305684876.27 1180328078.32 11514496059.2
# 805254809.414
#  1314539488.5 1087364289.12 5274356133.43
# 777643743.624
#  1286369314.32 1053097684.38 4085299725.97
# 704219282.592
#  1201621676.66 989191447.575 2791589197.6
# 739255311.92
#  1246589398.85 1124882983.76 6813731729.68
# 465.642435532
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.py:293: UserWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg)

# %% [markdown]
# ### Test using 2D grid as before

# %%
t_start = time.clock()

N_pts = 5
x = np.linspace(0.02, 0.25, N_pts)
y = np.linspace(0.1, 1.0, N_pts)
theta1, theta2 = np.meshgrid(x, y)

b_int = p_true_3[0] * np.ones([N_pts, N_pts])
theta3 = p_true_3[3] * np.ones([N_pts, N_pts])

like_i = np.array([])
for i in np.arange(len(b_int.flatten())):
    p_test = p_true_3.copy()
    p_test[1] = theta1.flatten()[i]
    p_test[2] = theta2.flatten()[i]

    ln_like = ln_likelihood_test_2(p_test, DWD_3)
    like_i = np.append(like_i, np.sum(ln_like))

print "Elapsed time:", time.clock() - t_start, "seconds"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-514-dc77894001f1> in <module>()
#      15     p_test[2] = theta2.flatten()[i]
#      16
# ---> 17     ln_like = ln_likelihood_test_2(p_test, DWD_3)
#      18     like_i = np.append(like_i, np.sum(ln_like))
#      19
#
# <ipython-input-512-71b6733f2e8f> in ln_likelihood_test_2(p, DWD)
#      75         my_args = (p, delta_cool,delta_cool_err,sys["m1_wd"],sys["m1_wd_err"],sys["m2_wd"],sys["m2_wd_err"])
#      76
# ---> 77         P_sys, P_sys_err = integrate.dblquad(integrand, t_l, t_h, lambda x: t2_limits[1], lambda x: t2_limits[0], args=my_args, epsabs=1.0, epsrel=1.0)
#      78 #        P_sys, P_sys_err = integrate.dblquad(integrand, t_l, t_h, t_min, t_max, args=my_args, epsabs=1.0, epsrel=1.0)
#      79
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.pyc in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     431
#     432     """
# --> 433     return quad(_infunc,a,b,(func,gfun,hfun,args),epsabs=epsabs,epsrel=epsrel)
#     434
#     435
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.pyc in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     250         args = (args,)
#     251     if (weight is None):
# --> 252         retval = _quad(func,a,b,args,full_output,epsabs,epsrel,limit,points)
#     253     else:
#     254         retval = _quad_weight(func,a,b,args,full_output,epsabs,epsrel,limlst,limit,maxp1,weight,wvar,wopts)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.pyc in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     315     if points is None:
#     316         if infbounds == 0:
# --> 317             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     318         else:
#     319             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.pyc in _infunc(x, func, gfun, hfun, more_args)
#     379     b = hfun(x)
#     380     myargs = (x,) + more_args
# --> 381     return quad(func,a,b,args=myargs)[0]
#     382
#     383
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.pyc in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     250         args = (args,)
#     251     if (weight is None):
# --> 252         retval = _quad(func,a,b,args,full_output,epsabs,epsrel,limit,points)
#     253     else:
#     254         retval = _quad_weight(func,a,b,args,full_output,epsabs,epsrel,limlst,limit,maxp1,weight,wvar,wopts)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/integrate/quadpack.pyc in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     315     if points is None:
#     316         if infbounds == 0:
# --> 317             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     318         else:
#     319             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-512-71b6733f2e8f> in integrand(y, x, p, delta_cool, delta_cool_err, m1, m1_err, m2, m2_err)
#       4 def integrand(y, x, p, delta_cool, delta_cool_err, m1, m1_err, m2, m2_err):
#       5
# ----> 6     M_zams = np.array([func_lifetime_inv(x), func_lifetime_inv(y)])
#       7     M_wd = get_m_wd(p, M_zams)
#       8
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/polyint.pyc in __call__(self, x)
#      52         """
#      53         x, x_shape = self._prepare_x(x)
# ---> 54         y = self._evaluate(x)
#      55         return self._finish_y(y, x_shape)
#      56
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     446         #    The behavior is set by the bounds_error variable.
#     447         x_new = asarray(x_new)
# --> 448         out_of_bounds = self._check_bounds(x_new)
#     449         y_new = self._call(self, x_new)
#     450         if len(y_new) > 0:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/interpolate/interpolate.pyc in _check_bounds(self, x_new)
#     481         # !! Should we emit a warning if some values are out of bounds?
#     482         # !! matlab does not.
# --> 483         out_of_bounds = logical_or(below_bounds, above_bounds)
#     484         return out_of_bounds
#     485
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()

like_temp = np.copy(like_i)
like_temp[np.where(like_i < max(like_i)-30.0)] = max(like_i)-30.0
like_temp = like_temp.reshape(N_pts, N_pts)

p = ax.pcolor(theta1, theta2, like_temp, cmap='RdBu', vmin=np.min(like_temp), vmax=np.max(like_temp))
cb = fig.colorbar(p, ax=ax)

ax.axvline(p_true_3[1], color='k')
ax.axhline(p_true_3[2], color='k')

x_max = theta1.flatten()[np.argmax(like_temp)]
y_max = theta2.flatten()[np.argmax(like_temp)]
    
plt.xlim(0.02,0.25)    
plt.ylim(0.1,1.0)    

plt.xlabel(r'$\theta_1$')
plt.ylabel(r'$\theta_2$')
    
ax.scatter(x_max, y_max, color='c')
    
print r"Highest likelihood: $\theta_1=$", x_max, r'$\theta_2=$', y_max
    
#plt.savefig('../figures/likelihood_test_2D_N20_err03.pdf')
plt.show()
# Out:
# Highest likelihood: $\theta_1=$ 0.1925 $\theta_2=$ 0.55
